# %%
import pandas as pd

df = pd.read_csv('C:\\Users\Boss\Desktop\Fish.csv')


bream=df[df['Species']=='Bream']
roach=df[df['Species']=='Roach']
whitefish=df[df['Species']=='Whitefish']
parkki=df[df['Species']=='Parkki']
perch=df[df['Species']=='Perch']
pike=df[df['Species']=='Pike']
smelt=df[df['Species']=='Smelt']

df.head()
# Out:
#   Species  Weight  Length1  Length2  Length3   Height   Width
# 0   Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1   Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2   Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3   Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4   Bream   430.0     26.5     29.0     34.0  12.4440  5.1340

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

plt.figure(figsize=(20,20))
plt.plot( 'Weight', 'Species', data=smelt, marker='o', markerfacecolor='purple', markersize=12, color='purple', linewidth=4)
plt.plot( 'Weight', 'Species', data=pike, marker='o', markerfacecolor='blue', markersize=12, color='blue', linewidth=4)
plt.plot( 'Weight', 'Species', data=perch, marker='o', markerfacecolor='skyblue', markersize=12, color='skyblue', linewidth=4)
plt.plot( 'Weight', 'Species', data=parkki, marker='o', markerfacecolor='green', markersize=12, color='green', linewidth=4)
plt.plot('Weight', 'Species', data=whitefish, marker='o', markerfacecolor='yellow', markersize=12, color='yellow', linewidth=4)
plt.plot( 'Weight', 'Species', data=roach, marker='o', markerfacecolor='orange', markersize=12, color='orange', linewidth=4)
plt.plot( 'Weight', 'Species', data=bream, marker='o', markerfacecolor='red', markersize=12, color='red', linewidth=4)


plt.show()

# %%
list=df['Species'].unique()
med=[]
for i in list:
    a=(df[df['Species']==i])
    med.append(a['Weight'].mean())
    print(i, a['Weight'].mean())
# Out:
# Bream 617.8285714285714
# Roach 152.05
# Whitefish 531.0
# Parkki 154.8181818181818
# Perch 382.23928571428576
# Pike 718.7058823529412
# Smelt 11.17857142857143

# %%
print(med)
# Out:
# [617.8285714285714, 152.05, 531.0, 154.8181818181818, 382.23928571428576, 718.7058823529412, 11.17857142857143]

# %%
med_all=df['Weight'].mean()
print(med_all)
# Out:
# 398.3264150943396

# %%
ssw=0
for i in list:
     a=df[df['Species']==i]
     medi=a["Weight"].mean()
     for j in a["Weight"]:
        ssw+=(j-medi)**2
print(ssw)
# Out:
# 12732411.244346822

# %%
ssb=0
for i in list:
     a=df[df['Species']==i]
     medi=a["Weight"].mean()
     c=a['Weight'].count()
     ssb+=c*(medi-med_all)**2
print(ssb)
# Out:
# 7515047.824709775

# %%
print(ssb+ssw)
sst=0
for i in df["Weight"]:
    sst+=(i-med_all)**2
print(sst)
# Out:
# 20247459.069056597
# 20247459.069056608

# %%
msb=ssb/6
msw=ssw/158

# %%
print("F=", msb/msw)
# Out:
# F= 15.542716582602514

# %%
if(msb/msw>2.17):
    print("h0 not correct")
# Out:
# h0 not correct
